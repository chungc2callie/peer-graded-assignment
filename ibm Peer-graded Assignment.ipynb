# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Callie**
#
# Data Scientists

# %% [markdown]
# *I am interested in data science because data is everywhere and the core foundation of every company. The ability to read and understand data could solve so many problems and create better effective solutions.*

# %% [markdown]
# ### The code below in cell 5 will show the output for 1+1 which will equal 2

# %%
1+1
# Out:
# 2

# %% [markdown]
# - bullet 1
# - bullet 2
# - bullet 3
# ---
# ~~Scratch this.~~
